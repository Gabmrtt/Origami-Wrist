# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dffSMA56D20smp = pd.read_csv('SMA56ALLSMP-D20 - Copy.txt.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA56D20 =  pd.read_csv('SMA56NOSMP-D20',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffX9101112 = pd.read_csv('X12800EQUIV9-10-11-12.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12
dffX78 = pd.read_csv('X12800Equiv7-8.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time'])
dffX910 = pd.read_csv('X12800Equiv9-10.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time'])
dffX912 = pd.read_csv('X12800EQUIV11-12.2.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time'])
dffX1011 = pd.read_csv('X12800Equiv10-11.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time'])
dffX1112 = pd.read_csv('X12800Equiv11-12.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time'])

# %%
#df = pd.read_csv('27.11.csv', names = ['Fx','Fy','Fz','Tx','Ty','Tz','else'])
df = pd.read_excel('27.11.Forces.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-44ccf64f37fc> in <module>
#       1 #df = pd.read_csv('27.11.csv', names = ['Fx','Fy','Fz','Tx','Ty','Tz','else'])
# ----> 2 df = pd.read_excel('27.11.Forces.xlsx')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
plt.plot(df['Fx'])

# %%
plt.plot(df['Fy'])

# %%
df['Fx'] = df['Fx'] - df['Fx'].iloc[0]
df['Fy'] = df['Fy'] - df['Fy'].iloc[0]
df['Fx'] = -1 * df['Fx']
df['Force'] = (df['Fx']*df['Fx']+df['Fy']*df['Fy'])**0.5

# %%
plt.plot(df['Fx'], label = 'Fx')
plt.plot(df['Fy'], label = 'Fy')
plt.legend(loc ='best')

# %%
plt.plot(df['Force'])
