# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dffSMA3456D20smp = pd.read_csv('SMA3456ALLSMP-D20 - Copy.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA3456D20 =  pd.read_csv('SMA3456NOSMP-D20.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffSMA3456D25 = pd.read_csv('SMA3456NOSMP-D25.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12
dffSMA34D20smp = pd.read_csv('SMA34ALLSMP-D20 - Copy.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA34D20 =  pd.read_csv('SMA34NOSMP-D20.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffSMA34D25 = pd.read_csv('SMA34NOSMP-D25.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12
dffSMA56D20smp = pd.read_csv('SMA56ALLSMP-D20 - Copy.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA56D20 =  pd.read_csv('SMA56NOSMP-D20.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffSMA56D25 = pd.read_csv('SMA56NOSMP-D25.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12
dffSMA46D20smp = pd.read_csv('SMA46ALLSMP-D20 - Copy.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA46D20 =  pd.read_csv('SMA46NOSMP-D20.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffSMA46D25 = pd.read_csv('SMA46NOSMP-D25.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12
dffSMA35D20smp = pd.read_csv('SMA35ALLSMP-D20 - Copy.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X All equiv
dffSMA35D20 =  pd.read_csv('SMA35NOSMP-D20.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X No equiv
dffSMA35D25 = pd.read_csv('SMA35NOSMP-D25.txt',names = ['Fx','Fy','Fz','Tx','Ty','Tz','Time']) #X equiv 9-10-11-12

d = ([dffSMA56D20smp,dffSMA56D20,dffSMA56D25,dffSMA34D25,dffSMA34D20,dffSMA34D20smp,dffSMA3456D20smp,dffSMA3456D20,
      dffSMA3456D25,dffSMA35D20,dffSMA35D25,dffSMA35D20smp,dffSMA46D20smp,dffSMA46D20,dffSMA46D25])
for df in d: 
    df['Time'] = df['Time']-df['Time'][0]
    df['Time'] = df['Time']/1000
    df['Fx'] = -1*df['Fx']
    df['Fx'] = df['Fx'] - df['Fx'][0]
    df['Fy'] = df['Fy'] - df['Fy'][0]
    df['Fz'] = df['Fz'] - df['Fz'][0]

# %%
plt.plot(dffSMA56D20['Time'],dffSMA56D20['Fx'], label = 'SMA 5-6 D20')
plt.plot(dffSMA56D25['Time'],dffSMA56D25['Fx'], label = 'SMA 5-6 D25')
plt.plot(dffSMA56D20smp['Time'],dffSMA56D20smp['Fx'], label = 'SMA 5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA56D20['Time'],dffSMA56D20['Fy'], label = 'SMA 5-6 D20')
plt.plot(dffSMA56D25['Time'],dffSMA56D25['Fy'], label = 'SMA 5-6 D25')
plt.plot(dffSMA56D20smp['Time'],dffSMA56D20smp['Fy'], label = 'SMA 5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA56D20['Time'],dffSMA56D20['Fz'], label = 'SMA 5-6 D20')
plt.plot(dffSMA56D25['Time'],dffSMA56D25['Fz'], label = 'SMA 5-6 D25')
plt.plot(dffSMA56D20smp['Time'],dffSMA56D20smp['Fz'], label = 'SMA 5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fz (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA34D20['Time'],dffSMA34D20['Fx'], label = 'SMA 3-4 D20')
plt.plot(dffSMA34D25['Time'],dffSMA34D25['Fx'], label = 'SMA 3-4 D25')
plt.plot(dffSMA34D20smp['Time'],dffSMA34D20smp['Fx'], label = 'SMA 3-4 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA34D20['Time'],dffSMA34D20['Fy'], label = 'SMA 3-4 D20')
plt.plot(dffSMA34D25['Time'],dffSMA34D25['Fy'], label = 'SMA 3-4 D25')
plt.plot(dffSMA34D20smp['Time'],dffSMA34D20smp['Fy'], label = 'SMA 3-4 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA34D20['Time'],dffSMA34D20['Fz'], label = 'SMA 3-4 D20')
plt.plot(dffSMA34D25['Time'],dffSMA34D25['Fz'], label = 'SMA 3-4 D25')
plt.plot(dffSMA34D20smp['Time'],dffSMA34D20smp['Fz'], label = 'SMA 3-4 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fz (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA3456D20['Time'],dffSMA3456D20['Fy'],label = 'SMA 3-4-5-6 D20')
plt.plot(dffSMA3456D25['Time'],dffSMA3456D25['Fy'], label = 'SMA 3-4-5-6 D25')
plt.plot(dffSMA3456D20smp['Time'],dffSMA3456D20smp['Fy'], label = 'SMA 3-4-5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA3456D20['Time'],dffSMA3456D20['Fx'],label = 'SMA 3-4-5-6 D20')
plt.plot(dffSMA3456D25['Time'],dffSMA3456D25['Fx'], label = 'SMA 3-4-5-6 D25')
plt.plot(dffSMA3456D20smp['Time'],dffSMA3456D20smp['Fx'], label = 'SMA 3-4-5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA35D20['Time'],dffSMA35D20['Fx'],label = 'SMA 3-5 D20')
plt.plot(dffSMA35D25['Time'],dffSMA35D25['Fx'], label = 'SMA 3-5 D25')
plt.plot(dffSMA35D20smp['Time'],dffSMA35D20smp['Fx'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA46D20['Time'],dffSMA46D20['Fx'],label = 'SMA 3-5 D20')
plt.plot(dffSMA46D25['Time'],dffSMA46D25['Fx'], label = 'SMA 3-5 D25')
plt.plot(dffSMA46D20smp['Time'],dffSMA46D20smp['Fx'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.legend(loc = 'best')
plt.show()

# %%
fig = plt.figure(2, figsize = (7,5))
plt.plot(dffSMA3456D20['Time'],dffSMA3456D20['Fx'],label = 'SMA 3-4-5-6 D20')
plt.plot(dffSMA3456D25['Time'],dffSMA3456D25['Fx'], label = 'SMA 3-4-5-6 D25')
plt.plot(dffSMA3456D20smp['Time'],dffSMA3456D20smp['Fx'], label = 'SMA 3-4-5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc='lower center', bbox_to_anchor=(0.3, 0, 0, 0))
plt.show()


fig = plt.figure(2, figsize = (7,5))
plt.plot(dffSMA3456D20['Time'],dffSMA3456D20['Fy'],label = 'SMA 3-4-5-6 D20')
plt.plot(dffSMA3456D25['Time'],dffSMA3456D25['Fy'], label = 'SMA 3-4-5-6 D25')
plt.plot(dffSMA3456D20smp['Time'],dffSMA3456D20smp['Fy'], label = 'SMA 3-4-5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

fig = plt.figure(2, figsize = (7,5))
plt.plot(dffSMA3456D20['Time'],dffSMA3456D20['Fz'],label = 'SMA 3-4-5-6 D20')
plt.plot(dffSMA3456D25['Time'],dffSMA3456D25['Fz'], label = 'SMA 3-4-5-6 D25')
plt.plot(dffSMA3456D20smp['Time'],dffSMA3456D20smp['Fz'], label = 'SMA 3-4-5-6 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fz (N)')
plt.legend(loc = 'best')
plt.show()

# %%
plt.plot(dffSMA35D20['Time'],dffSMA35D20['Fx'],label = 'SMA 3-5 D20')
plt.plot(dffSMA35D25['Time'],dffSMA35D25['Fx'], label = 'SMA 3-5 D25')
plt.plot(dffSMA35D20smp['Time'],dffSMA35D20smp['Fx'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA35D20['Time'],dffSMA35D20['Fy'],label = 'SMA 3-5 D20')
plt.plot(dffSMA35D25['Time'],dffSMA35D25['Fy'], label = 'SMA 3-5 D25')
plt.plot(dffSMA35D20smp['Time'],dffSMA35D20smp['Fy'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA35D20['Time'],dffSMA35D20['Fz'],label = 'SMA 3-5 D20')
plt.plot(dffSMA35D25['Time'],dffSMA35D25['Fz'], label = 'SMA 3-5 D25')
plt.plot(dffSMA35D20smp['Time'],dffSMA35D20smp['Fz'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fz (N)')
plt.legend(loc = 'best')
plt.show()

# %%
plt.plot(dffSMA46D20['Time'],dffSMA46D20['Fx'],label = 'SMA 3-5 D20')
plt.plot(dffSMA46D25['Time'],dffSMA46D25['Fx'], label = 'SMA 3-5 D25')
plt.plot(dffSMA46D20smp['Time'],dffSMA46D20smp['Fx'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fx (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA46D20['Time'],dffSMA46D20['Fy'],label = 'SMA 3-5 D20')
plt.plot(dffSMA46D25['Time'],dffSMA46D25['Fy'], label = 'SMA 3-5 D25')
plt.plot(dffSMA46D20smp['Time'],dffSMA46D20smp['Fy'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fy (N)')
plt.legend(loc = 'best')
plt.show()

plt.plot(dffSMA46D20['Time'],dffSMA46D20['Fz'],label = 'SMA 3-5 D20')
plt.plot(dffSMA46D25['Time'],dffSMA46D25['Fz'], label = 'SMA 3-5 D25')
plt.plot(dffSMA46D20smp['Time'],dffSMA46D20smp['Fz'], label = 'SMA 3-5 D20 All SMP')
plt.xlabel('Time (s)')
plt.ylabel('Fz (N)')
plt.legend(loc = 'best')
plt.show()

# %%
#df = pd.read_csv('27.11.csv', names = ['Fx','Fy','Fz','Tx','Ty','Tz','else'])
df = pd.read_excel('27.11.Forces.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-44ccf64f37fc> in <module>
#       1 #df = pd.read_csv('27.11.csv', names = ['Fx','Fy','Fz','Tx','Ty','Tz','else'])
# ----> 2 df = pd.read_excel('27.11.Forces.xlsx')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
plt.plot(df['Fx'])

# %%
plt.plot(df['Fy'])

# %%
df['Fx'] = df['Fx'] - df['Fx'].iloc[0]
df['Fy'] = df['Fy'] - df['Fy'].iloc[0]
df['Fx'] = -1 * df['Fx']
df['Force'] = (df['Fx']*df['Fx']+df['Fy']*df['Fy'])**0.5

# %%
plt.plot(df['Fx'], label = 'Fx')
plt.plot(df['Fy'], label = 'Fy')
plt.legend(loc ='best')

# %%
plt.plot(df['Force'])
